# %%
import tensorflow as tf
# Out:
# /home/trungdv/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
saver = tf.train.import_meta_graph('../../../saved_models/attention_aps_word/csp.ckpt.meta')

# %%
test = tf.get_variable('test', shape=(640,))
saver = tf.train.Saver(var_list={"decoder/decoder_emb_layer/bias": test})
sess = tf.Session()
saver.restore(sess, '../../../saved_models/attention_aps_word/csp.epoch9.ckpt')
# Out:
# INFO:tensorflow:Restoring parameters from ../../../saved_models/attention_aps_word/csp.epoch9.ckpt

# %%
sess.run(test)
# Out:
# array([-0.24302894, -0.13452332,  0.13778412,  0.4181844 , -0.2807858 ,
#        -0.13901822, -0.04568383,  0.22260761,  0.09094474,  0.6700925 ,
#        -0.16703634, -0.16142195,  0.35394078,  0.23205622,  0.18132854,
#        -0.04569358, -0.35987929, -0.17446133,  0.05369783, -0.17193237,
#         0.14644158,  0.08893888, -0.10478386,  0.01974127, -0.04741135,
#         0.00595654, -0.3480479 , -0.0553923 , -0.45492446,  0.33283678,
#         0.134259  , -0.18171854, -0.34077454,  0.17140777,  0.17031962,
#         0.1981895 , -0.31874624, -0.17278925,  0.12557676, -0.09605271,
#         0.18933262,  0.24912584,  0.18818836, -0.49907175, -0.0150537 ,
#         0.06777078, -0.16502857,  0.32100925, -0.2955634 , -0.13362518,
#         0.1268834 ,  0.0378838 , -0.16685362, -0.07300116, -0.1354735 ,
#         0.31770766,  0.08856738, -0.10474072, -0.28787303, -0.38150796,
#        -0.18176472, -0.38028568,  0.40870193,  0.39031518,  0.01897862,
# ...
