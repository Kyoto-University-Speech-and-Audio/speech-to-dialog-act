# %%
#! /usr/bin/env python
# -*- coding: utf-8 -*-

"""Make target labels for the End-to-End model (LDC97S62 corpus)."""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import re
from tqdm import tqdm
from collections import OrderedDict

import os, glob
DATA_FOLDER = "/n/sd7/trung/csp/data/swbd"

#from swbd.labels.ldc97s62.word_boundary import read_segmentation
#from swbd.labels.ldc97s62.fix_trans import fix_transcript
#from utils.labels.character import Char2idx
#from utils.labels.word import Word2idx
#from utils.util import mkdir_join

# NOTE:
############################################################
# [character]
# 26 alphabets(a-z), number(0-9), space(_), apostorophe('), hyphen(-)
# laughter(L), noise(N), vocalized-noise(V)
# = 42 labels

# [character_capital_divide]
# 26 lower alphabets(a-z), 26 upper alphabets(A-Z),
# 22 special double-letters, apostorophe('), hyphen(-),
# laughter(L), noise(N), vocalized-noise(V)
# = 92 labels

# [word]
# Original: ? labels + OOV
############################################################

DOUBLE_LETTERS = ['aa', 'bb', 'cc', 'dd', 'ee', 'ff', 'gg', 'hh', 'ii', 'jj',
                  'kk', 'll', 'mm', 'nn', 'oo', 'pp', 'qq', 'rr', 'ss', 'tt',
                  'uu', 'vv', 'ww', 'xx', 'yy', 'zz']
SPACE = '_'
HYPHEN = '-'
APOSTROPHE = '\''
LAUGHTER = 'LA'
NOISE = 'NZ'
VOCALIZED_NOISE = 'VN'
OOV = 'OOV'

# %%
def read_trans(label_paths, word_boundary_paths, run_root_path,
               vocab_file_save_path,
               save_vocab_file=False,  speaker_dict_fisher=None,
               char_set=None, char_capital_set=None, word_count_dict=None):
    """Read transcripts (*_trans.txt) & save files (.npy).
    Args:
        label_paths (list): list of paths to label files
        word_boundary_paths (list): list of paths to word boundary files
        run_root_path (string):
        vocab_file_save_path (string): path to vocabulary files
        save_vocab_file (bool, optional): if True, save vocabulary files
        speaker_dict_fisher (dict):
        char_set (set):
        char_capital_set (set):
        word_count_dict (dict):
    Returns:
        speaker_dict: dictionary of speakers
            key (string) => speaker
            value (dict) => dictionary of utterance infomation of each speaker
                key (string) => utterance index
                value (list) => [start_frame, end_frame, char_indices, char_indices_capital,
                                word_freq1_indices, word_freq5_indices,
                                word_freq10_indices, word_freq15_indices]
    """
    print('=====> Processing target labels...')
    speaker_dict = OrderedDict()
    char_set, char_capital_set = set([]), set([])
    word_count_dict = {}
    vocab_set = set([])

    for label_path in zip(tqdm(label_paths)):
        assert label_path == wb_path.replace('word', 'trans')
        utterance_dict = OrderedDict()
        segmentation_dict = read_segmentation(wb_path)
        with open(label_path, 'r') as f:
            for line in f:
                line = line.strip().lower().split(' ')
                speaker = line[0].split('-')[0]
                # Fix speaker name
                speaker = speaker.replace('sw0', 'sw').replace(
                    'a', '-A').replace('b', '-B')
                utt_index = line[0].split('-')[-1]
                start_frame = int(float(line[1]) * 100 + 0.05)
                end_frame = int(float(line[2]) * 100 + 0.05)
                transcript = ' '.join(line[3:])

                if transcript == '[silence]':
                    continue

                # Divide into short utterances
                length_threshold = 700
                if end_frame - start_frame >= length_threshold:
                    word_info_list = segmentation_dict[utt_index]
                    divide_points = []
                    divided_trans = []
                    partial_word_list = []
                    start_frame_tmp = start_frame
                    for i, word_info in enumerate(word_info_list):
                        if word_info[2] != '':
                            partial_word_list.append(word_info[2])
                        if 0 < i < len(word_info_list) - 1 and word_info[2] == '' and word_info[1] - start_frame_tmp >= length_threshold:
                            divide_points.append(
                                int((word_info[1] + word_info[0]) / 2))
                            divided_trans.append(' '.join(partial_word_list))
                            partial_word_list = []
                            start_frame_tmp = word_info[0]

                    # Last segment
                    if len(partial_word_list) > 0:
                        divided_trans.append(' '.join(partial_word_list))

                    if len(divide_points) > 0:
                        transcript_list = divided_trans
                    else:
                        transcript_list = [transcript]
                else:
                    divide_points = []
                    transcript_list = [transcript]

                for i_trans, trans in enumerate(transcript_list):
                    # Clean transcript
                    trans = fix_transcript(trans)

                    # Convert space to "_"
                    trans = re.sub(r'\s', SPACE, trans)

                    # Skip silence, laughter, noise, vocalized-noise
                    if trans.replace(NOISE, '').replace(LAUGHTER, '').replace(VOCALIZED_NOISE, '').replace(SPACE, '') == '':
                        continue

                    # Remove the first and last space
                    if trans[0] == SPACE:
                        trans = trans[1:]
                    if trans[-1] == SPACE:
                        trans = trans[:-1]

                    # Count words
                    for word in trans.split(SPACE):
                        vocab_set.add(word)
                        if word not in word_count_dict.keys():
                            word_count_dict[word] = 0
                        word_count_dict[word] += 1

                    # Capital-divided
                    trans_capital = ''
                    for word in trans.split(SPACE):
                        if len(word) == 1:
                            char_capital_set.add(word)
                            trans_capital += word
                        else:
                            # Replace the first character with the capital
                            # letter
                            word = word[0].upper() + word[1:]

                            # Check double-letters
                            for i in range(0, len(word) - 1, 1):
                                if word[i:i + 2] in DOUBLE_LETTERS:
                                    char_capital_set.add(word[i:i + 2])
                                else:
                                    char_capital_set.add(word[i])
                            trans_capital += word

                    for c in list(trans):
                        char_set.add(c)

                    if len(transcript_list) == 1:
                        utterance_dict[utt_index.zfill(4)] = [
                            start_frame, end_frame, trans]
                    else:
                        assert len(transcript_list) - 1 == len(divide_points)
                        if i_trans == 0:
                            assert start_frame < divide_points[i_trans] - 1
                            utterance_dict[utt_index.zfill(4) + '-' + str(i_trans + 1)] = [
                                start_frame, divide_points[0] - 1, trans]
                        elif i_trans == len(transcript_list) - 1:
                            assert start_frame < end_frame
                            utterance_dict[utt_index.zfill(4) + '-' + str(i_trans + 1)] = [
                                divide_points[-1], end_frame, trans]
                        else:
                            assert divide_points[i_trans -
                                                 1] < divide_points[i_trans] - 1
                            utterance_dict[utt_index.zfill(4) + '-' + str(i_trans + 1)] = [
                                divide_points[i_trans - 1], divide_points[i_trans] - 1, trans]

                    # for debug
                    # print(transcript_original)
                    # print(trans)
                    # print(trans_capital)

            speaker_dict[speaker] = utterance_dict

    # Make vocabulary files
    data_size = '2000h' if merge_with_fisher else '300h'
    #char_vocab_file_path = mkdir_join(
    #    vocab_file_save_path, 'character_' + data_size + '.txt')
    #char_capital_vocab_file_path = mkdir_join(
    #    vocab_file_save_path, 'character_capital_divide_' + data_size + '.txt')
    word_freq1_vocab_file_path = mkdir_join(
        vocab_file_save_path, 'word_freq1_' + data_size + '.txt')
    word_freq5_vocab_file_path = mkdir_join(
        vocab_file_save_path, 'word_freq5_' + data_size + '.txt')
    #word_freq10_vocab_file_path = mkdir_join(
    #    vocab_file_save_path, 'word_freq10_' + data_size + '.txt')
    #word_freq15_vocab_file_path = mkdir_join(
    #    vocab_file_save_path, 'word_freq15_' + data_size + '.txt')

    # Reserve some indices
    for mark in [SPACE, HYPHEN, APOSTROPHE, LAUGHTER, NOISE, VOCALIZED_NOISE]:
        for c in list(mark):
            char_set.discard(c)
    for mark in [SPACE, HYPHEN, APOSTROPHE]:
        for c in list(mark):
            char_capital_set.discard(c)

    # for debug
    # print(sorted(list(char_set)))
    # print(sorted(list(char_capital_set)))

    if save_vocab_file:
        # character-level
        with open(char_vocab_file_path, 'w') as f:
            char_list = sorted(list(char_set)) + \
                [SPACE, APOSTROPHE, HYPHEN, LAUGHTER, NOISE, VOCALIZED_NOISE]
            for char in char_list:
                f.write('%s\n' % char)

        # character-level (capital-divided)
        #with open(char_capital_vocab_file_path, 'w') as f:
        #    char_capital_list = sorted(list(char_capital_set)) + \
        #        [APOSTROPHE, HYPHEN, LAUGHTER, NOISE, VOCALIZED_NOISE]
        #    for char in char_capital_list:
        #        f.write('%s\n' % char)

        # word-level (threshold == 1)
        with open(word_freq1_vocab_file_path, 'w') as f:
            vocab_list = sorted(list(vocab_set)) + [OOV]
            for word in vocab_list:
                f.write('%s\n' % word)

        # word-level (threshold == 5)
        with open(word_freq5_vocab_file_path, 'w') as f:
            vocab_list = sorted([word for word, freq in list(word_count_dict.items())
                                 if freq >= 5]) + [OOV]
            for word in vocab_list:
                f.write('%s\n' % word)

        # word-level (threshold == 10)
        #with open(word_freq10_vocab_file_path, 'w') as f:
        #    vocab_list = sorted([word for word, freq in list(word_count_dict.items())
        #                         if freq >= 10]) + [OOV]
        #    for word in vocab_list:
        #       f.write('%s\n' % word)

        # word-level (threshold == 15)
        #with open(word_freq15_vocab_file_path, 'w') as f:
        #    vocab_list = sorted([word for word, freq in list(word_count_dict.items())
        #                         if freq >= 15]) + [OOV]
        #    for word in vocab_list:
        #        f.write('%s\n' % word)

    # Tokenize
    print('=====> Tokenize...')
    #char2idx = Char2idx(char_vocab_file_path, double_letter=True)
    #char2idx_capital = Char2idx(
    #    char_capital_vocab_file_path, capital_divide=True)
    word2idx_freq1 = Word2idx(word_freq1_vocab_file_path)
    word2idx_freq5 = Word2idx(word_freq5_vocab_file_path)
    #word2idx_freq10 = Word2idx(word_freq10_vocab_file_path)
    #word2idx_freq15 = Word2idx(word_freq15_vocab_file_path)
    for speaker, utt_dict in tqdm(speaker_dict.items()):
        for utt_index, [start_frame, end_frame, transcript] in utt_dict.items():
            #char_indices = char2idx(transcript)
            #char_indices_capital = char2idx_capital(transcript)
            word_freq1_indices = word2idx_freq1(transcript)
            word_freq5_indices = word2idx_freq5(transcript)
            #word_freq10_indices = word2idx_freq10(transcript)
            #word_freq15_indices = word2idx_freq15(transcript)

            #char_indices = ' '.join(list(map(str, char_indices.tolist())))
            #char_indices_capital = ' '.join(
            #    list(map(str, char_indices_capital.tolist())))
            word_freq1_indices = ' '.join(
                list(map(str, word_freq1_indices.tolist())))
            word_freq5_indices = ' '.join(
                list(map(str, word_freq5_indices.tolist())))
            #word_freq10_indices = ' '.join(
            #    list(map(str, word_freq10_indices.tolist())))
            #word_freq15_indices = ' '.join(
            #    list(map(str, word_freq15_indices.tolist())))

            #utt_dict[utt_index] = [start_frame, end_frame,
            #                       char_indices, char_indices_capital,
            #                       word_freq1_indices, word_freq5_indices,
            #                       word_freq10_indices, word_freq15_indices]
            utt_dict[utt_index] = [start_frame, end_frame,
                                   None, None,
                                   word_freq1_indices, word_freq5_indices,
                                   None, None]
        speaker_dict[speaker] = utt_dict

    return speaker_dict

# %%
print('=> Processing transcripts...')
speaker_dict_dict = {}  # dict of speaker_dict
print('---------- train ----------')

speaker_dict_dict['train'] = read_trans(
    label_paths=glob.glob(os.path.join(DATA_FOLDER, "ptree_transcripts", "alignments", '**/**')),
    word_boundary_paths=path.word(corpus='swbd'),
    run_root_path='./',
    vocab_file_save_path=mkdir_join('./config/vocab_files'),
    save_vocab_file=True)
# Out:
# => Processing transcripts...
# ---------- train ----------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-bc671de96d68> in <module>()
#       4
#       5 speaker_dict_dict['train'] = read_trans(
# ----> 6     label_paths=path.trans(corpus='swbd'),
#       7     word_boundary_paths=path.word(corpus='swbd'),
#       8     run_root_path='./',
#
# NameError: name 'path' is not defined

# %%
# Out:
# ['/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4812B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4792A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4108B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4049B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4137A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4626B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4333A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4340A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4148B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4691B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4784A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4137B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4114A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4812A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4726B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4026A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4834B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4363B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4312B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4327A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4826B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4022A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4080A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4072B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4821A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4682A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4565B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4372A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4154B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4770B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4940A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4679B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4681A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4707B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4004A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4092A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4880B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4608A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4074B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4830A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4114B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4831A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4666A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4362A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4646B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4936B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4617B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4630A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4802B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4051B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4056A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4159B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4378B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4376B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4688B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4745A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4709A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4443B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4886A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4774A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4133A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4321B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4129A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4608B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4859B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4483B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4644A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4147A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4379B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4038B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4814B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4004B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4675A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4101A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4644B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4321A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4902A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4340B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4316B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4108A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4347A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4617A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4099B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4028A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4725A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4336B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4078A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4785B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4334B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4615A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4655A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4829A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4056B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4038A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4019B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4716A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4785A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4049A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4123A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4175A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4130B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4314B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4023A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4339A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4092B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4341B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4796B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4181B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4345B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4333B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4886B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4876B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4752B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4174A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4036A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4082A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4936A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4829B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4370B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4080B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4572B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4358A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4628B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4380A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4905A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4765A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4788B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4360B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4633A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4697A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4382B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4048B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4152A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4181A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4064A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4177B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4618A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4096B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4605A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4008A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4723B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4902B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4728B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4611A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4314A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4079B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4681B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4655B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4103A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4880A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4799A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4320B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4840B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4716B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4311B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4603A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4082B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4013A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4364A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4721A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4801B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4060B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4013B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4339B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4127A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4725B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4327B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4618B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4153B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4765B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4050B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4380B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4611B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4628A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4358B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4037B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4890B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4378A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4325B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4758B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4150B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4153A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4071A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4032A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4774B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4379A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4168A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4055A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4927B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4130A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4072A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4064B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4077A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4353B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4784B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4023B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4707A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4165B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4868B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4336A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4802A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4735B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4646A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4735A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4033B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4366B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4703B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4060A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4691A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4363A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4055B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4619B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4633B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4318B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4138B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4364B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4642A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4168B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4443A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4877A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4675B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4147B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4788A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4316A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4917A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4312A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4175B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4908B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4733B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4366A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4113A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4548B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4376A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4649A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4026B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4660A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4129B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4184B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4752A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4565A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4642B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4341A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4096A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4927A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4905B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4154A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4698A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4334A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4720B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4048A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4342B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4319B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4138A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4071B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4928B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4822B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4626A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4330A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4726A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4890A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4801A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4113B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4148A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4077B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4728A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4666B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4721B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4868A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4723A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4697B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4519B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4758A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4822A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4099A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4356B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4720A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4659B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4090B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4078B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4659A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4345A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4346B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4051A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4019A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4859A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4736B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4318A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4770A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4166A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4346A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4856B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4858A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4682B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4615B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4519A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4101B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4028B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4356A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4917B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4733A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4605B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4347B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4830B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4834A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4603B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4329A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4928A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4649B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4940B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4109A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4150A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4826A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4155A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4158A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4184A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4171A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4703A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4353A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4127B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4133B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4630B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4679A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4109B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4104B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4858B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4745B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4165A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4325A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4123B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4349B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4155B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4382A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4342A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4159A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4151B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4759B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4319A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4079A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4821B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4033A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4103B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4036B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4572A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4174B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4856A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4660B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4104A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4876A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4688A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4840A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4831B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4372B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4362B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4177A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4008B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4329B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4759A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4698B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4796A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4814A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4483A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4799B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4166B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4360A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4152B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4032B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4171B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4320A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4311A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4792B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4349A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4330B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4908A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4149A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4050A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4037A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4149B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4877B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4736A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4619A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4158B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4074A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4370A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4022B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4151A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4548A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4090A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/4/sw4709B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2851A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2638B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2627A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2849A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2604B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2628A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2283A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2534B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2602A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2061B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2342A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2265A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2190A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2576B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2380A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2460A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2418A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2587A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2289B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2776A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2436B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2424B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2840B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2927B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2847B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2776B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2839A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2909A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2393B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2840A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2935B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2397A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2599B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2875A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2889B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2383A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2981B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2950A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2965B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2621B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2647B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2502A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2883A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2387A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2101A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2301B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2661B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2790A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2528B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2467A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2991A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2092A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2263A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2528A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2429B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2860B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2125B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2849B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2828A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2756A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2405B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2897A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2506A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2653B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2883B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2956B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2789B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2476A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2025B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2658B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2889A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2514A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2279B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2354A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2965A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2900A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2800B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2610A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2559B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2614A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2969B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2292B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2253B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2984A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2452A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2365A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2252B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2913A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2871A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2830A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2300B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2915B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2658A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2278B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2684B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2334B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2944A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2858A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2788B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2452B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2879B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2446A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2598B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2768A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2770B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2691A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2963B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2741A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2775B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2035B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2039B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2642A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2617A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2772B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2316A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2185B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2549A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2472A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2344B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2996B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2051A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2299A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2504B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2220A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2887A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2065A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2818B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2960A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2623A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2826B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2085B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2693B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2461B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2305B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2220B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2107A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2676A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2539B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2868B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2435A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2268A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2104B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2678A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2834B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2716B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2616A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2723A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2884A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2521B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2568B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2611A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2232B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2451A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2736A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2323B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2898B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2448B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2597B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2252A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2645B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2461A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2336A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2349A-ms98-a-penn.text',
# ...
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2548A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2181A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2565A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2340B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2723B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2499A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2924B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2278A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2051B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2455A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2676B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2689A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2820A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2910B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2137B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2679A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2627B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2024A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2754B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2334A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2575B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2151A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2130B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2389B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2663A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2293B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2437B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2858B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2983A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2040A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2355B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2953A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2376B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2479B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2110B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2960B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2227B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2237A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2761A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2426B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2295A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2870A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2353B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2631A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2249B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2679B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2434A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2862A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2460B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2178B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2434B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2482A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2154B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2072B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2145A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2995B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2028A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2342B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2652A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2726A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2710B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2486B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2876B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2836A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2262A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2736B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2526B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2759A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2471B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2794A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2163B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2366A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2372A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2149B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2870B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2184A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2110A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2589A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2086A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2157A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2268B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2594B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2640B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2323A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2982A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2490B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2836B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2006B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2648A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2830B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2441B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2945A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2743B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2634A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2313A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2967B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2228B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2229B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2121B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2071A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2884B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2383B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2575A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2433B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2717A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2226A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2570A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2749A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2570B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2548B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2708B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2622A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2289A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2820B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2010A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2571B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2614B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2237B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2875B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2436A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2427B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2455B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2035A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2448A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2623B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2060B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2957B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2304B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2145B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2707A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2263B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2803A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2784B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2578A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2515B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2432B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2546A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2382A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2603B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2610B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2511B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2999A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2598A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2308A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2774A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2724A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2959A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2205B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2093A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2241A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2558A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2711A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2085A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2713B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2773A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2784A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2295B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2450B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2101B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2285A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2437A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2386A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2368B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2821B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2266B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2465B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2344A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2032B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2393A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2191A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2792A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2842A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2467B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2599A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2800A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2759B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2584B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2662A-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2314B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2503B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2667B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2877B-ms98-a-penn.text',
#  '/n/sd7/trung/csp/data/swbd/ptree_transcripts/alignments/2/sw2839B-ms98-a-penn.text',
#  ...]
